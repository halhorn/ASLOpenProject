# %%
# youtube8m のディレクトリに移動
import os
while os.getcwd().split('/')[-1] != 'youtube8m': os.chdir('..')
os.getcwd()
# Out:
# '/home/jupyter/ASLOpenProject/youtube8m'

# %%
PROJECT = "qwiklabs-gcp-ml-3b4c41182bb8"  # Replace with your PROJECT
BUCKET = "qwiklabs-gcp-ml-3b4c41182bb8"  # Replace with your BUCKET
REGION = "us-central1"            # Choose an available region for Cloud MLE
TFVERSION = "1.14"                # TF version for CMLE to use

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
import shutil
from datetime import datetime
from data import read_dataset, CLASS_NUM
print(CLASS_NUM)
# Out:
# 3862

# %%
TRAIN_DATA_PATH = './data/video/train*.tfrecord'
EVAL_DATA_PATH = './data/video/validate*.tfrecord'

# %% [markdown]
# # Models
# 特徴量を受け取って、識別用の logits を出力するモデル

# %%
class LinearModel(tf.keras.models.Model):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.output_dense = tf.keras.layers.Dense(CLASS_NUM)
    
    def call(self, visual_feature, audio_feature):
        '''
        フィーチャーを受け取って sigmoid の logits を返します
        '''
        return self.output_dense(tf.concat([visual_feature, audio_feature], axis=-1))

# %% [markdown]
# # Model Function

# %%
from typing import Dict
from data import read_dataset

def create_model(params):
    model_map = {
        'linear': LinearModel,
    }
    return model_map[params['model']](params)

def multi_hot(indices):
    return tf.reduce_sum(tf.one_hot(indices, CLASS_NUM), axis=-2)

def recall_topk(probabilities, labels, top_k):
    predicted_topk = tf.math.top_k(probabilities, k=top_k).indices
    predicted_topk_multihot = multi_hot(predicted_topk)
    return tf.metrics.recall(
        labels=labels,
        predictions=predicted_topk_multihot,
    )

def create_metrics(probabilities, labels, params):
    threshold = params.get('threshold', 0.5)
    top_k = params.get('top_k', 5)
    predicted_bool = tf.cast(probabilities >= threshold, tf.float32)
    metrics = {
        'accuracy': tf.metrics.accuracy(labels=labels, predictions=predicted_bool),
        'recall': tf.metrics.recall(labels=labels, predictions=predicted_bool),
        'precision': tf.metrics.precision(labels=labels, predictions=predicted_bool),
        'auc': tf.metrics.auc(labels=labels, predictions=predicted_bool),
        'predicted_tag_count': tf.metrics.mean(tf.math.count_nonzero(predicted_bool, axis=-1)),
    }
    for k in [top_k // 2, top_k, top_k * 2]:
        metrics['recall_top{}'.format(k)] = recall_topk(probabilities, labels, top_k=k)
    return metrics

def model_fn(
    features: Dict[str, tf.Tensor],
    labels: tf.Tensor,
    mode: tf.estimator.ModeKeys,
    params: Dict,
) -> tf.estimator.EstimatorSpec:
    threshold = params.get('threshold', 0.5)
    model = create_model(params)
    logits = model(features['mean_rgb'], features['mean_audio'])
    probabilities = tf.nn.sigmoid(logits)

    loss = None
    train_op = None
    eval_metric_ops = None

    if mode == tf.estimator.ModeKeys.TRAIN or mode == tf.estimator.ModeKeys.EVAL:
        # Convert string label to int
        cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(
            labels=labels,
            logits=logits,
        )
        loss = tf.reduce_mean(cross_entropy)

    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer(learning_rate=params.get('learning_rate', 0.001))
        # Batch Normalization 用
        update_ops = tf.get_collection(key = tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(control_inputs = update_ops):
            train_op = optimizer.minimize(
                loss,
                global_step=tf.train.get_or_create_global_step()
            )
    if mode == tf.estimator.ModeKeys.EVAL:
        eval_metric_ops = create_metrics(probabilities, labels, params)

    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions={
            'probabilities': probabilities,
            'predicted_topk': tf.math.top_k(probabilities, k=params.get('top_k', 5)).indices,
        },
        loss=loss,
        train_op=train_op,
        eval_metric_ops=eval_metric_ops,
    )

# %% [markdown]
# # その他諸々

# %%
def serving_input_fn():
    feature_placeholders = {
        'mean_rgb': tf.placeholder(dtype=tf.float32, shape=[None, 1024], name='serving_mean_rgb'),
        'mean_audio': tf.placeholder(dtype=tf.float32, shape=[None, 128], name='serving_mean_audio'),
    }
    return tf.estimator.export.ServingInputReceiver(
        features=feature_placeholders,
        receiver_tensors=feature_placeholders,
    )

# %%
def train_and_evaluate(output_dir: str, params: Dict) -> None:
    tf.summary.FileWriterCache.clear()
    eval_interval = params.get('eval_interval', 60)

    config = tf.estimator.RunConfig(
        model_dir=output_dir,
        save_checkpoints_secs=eval_interval,
        log_step_count_steps=params.get('log_interval_step', 100),
    )
    estimator = tf.estimator.Estimator(
        model_fn=model_fn,
        config=config,
        params=params,
    )
    batch_size = params.get('batch_size', 512)
    train_spec = tf.estimator.TrainSpec(
        lambda: read_dataset(
            params['train_data_path'],
            tf.estimator.ModeKeys.TRAIN,
            batch_size,
        ),
        max_steps=params.get('train_steps', 10000),
    )
    exporter = tf.estimator.LatestExporter(
        name='exporter', 
        serving_input_receiver_fn=serving_input_fn,
    )
    eval_spec = tf.estimator.EvalSpec(
        lambda: read_dataset(
            params['eval_data_path'],
            tf.estimator.ModeKeys.EVAL,
            batch_size,
        ),
        exporters=exporter,
        start_delay_secs=params.get('eval_delay_sec', 60),
        throttle_secs=eval_interval,
    )

    # Run train_and_evaluate loop
    tf.estimator.train_and_evaluate(
        estimator=estimator, 
        train_spec=train_spec, 
        eval_spec=eval_spec,
    )

# %% [markdown]
# # 学習させる

# %%
model_name = 'base'
out_dir = 'trained/video/{}/{}'.format(model_name, datetime.now().strftime('%Y%m%d_%H%M%S'))
params = {
    'train_data_path': TRAIN_DATA_PATH,
    'eval_data_path': EVAL_DATA_PATH,
    'model': 'linear',
    'batch_size': 256,
    'learning_rate': 0.001,
    'train_steps': 30000,
    'log_interval_step': 1000,
    'eval_delay_sec': 1,
    'eval_interval': 10,
}

train_and_evaluate(out_dir, params)
# Out:
# INFO:tensorflow:Using config: {'_train_distribute': None, '_log_step_count_steps': 1000, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3010ce7908>, '_num_ps_replicas': 0, '_master': '', '_save_checkpoints_steps': None, '_device_fn': None, '_is_chief': True, '_experimental_distribute': None, '_eval_distribute': None, '_task_id': 0, '_service': None, '_task_type': 'worker', '_protocol': None, '_save_checkpoints_secs': 10, '_keep_checkpoint_max': 5, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_global_id_in_cluster': 0, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_num_worker_replicas': 1, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_model_dir': 'trained/video/base/20191209_064155'}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 10.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_sequence_example is deprecated. Please use tf.io.parse_single_sequence_example instead.
#
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:loss = 0.7076251, step = 0
# INFO:tensorflow:Saving checkpoints for 592 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/metrics_impl.py:2200: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:42:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-592
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:42:11
# INFO:tensorflow:Saving dict for global step 592: accuracy = 0.89090484, auc = 0.7587663, global_step = 592, loss = 0.40653038, precision = 0.004440042, predicted_tag_count = 422.08163, recall = 0.6264227, recall_top10 = 0.7591273, recall_top2 = 0.43092796, recall_top5 = 0.66653854
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 592: trained/video/base/20191209_064155/model.ckpt-592
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-592
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873731'/saved_model.pb
# INFO:tensorflow:global_step/sec: 71.5573
# INFO:tensorflow:loss = 0.29191077, step = 1000 (13.976 sec)
# INFO:tensorflow:global_step/sec: 300.494
# INFO:tensorflow:loss = 0.15850335, step = 2000 (3.328 sec)
# INFO:tensorflow:Saving checkpoints for 2549 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (10 secs).
# INFO:tensorflow:global_step/sec: 293.305
# INFO:tensorflow:loss = 0.10346818, step = 3000 (3.409 sec)
# INFO:tensorflow:global_step/sec: 303.07
# INFO:tensorflow:loss = 0.060982805, step = 4000 (3.301 sec)
# INFO:tensorflow:global_step/sec: 302.603
# INFO:tensorflow:loss = 0.03761478, step = 5000 (3.303 sec)
# INFO:tensorflow:Saving checkpoints for 5516 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:42:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-5516
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:42:31
# INFO:tensorflow:Saving dict for global step 5516: accuracy = 0.99935824, auc = 0.7450357, global_step = 5516, loss = 0.031714074, precision = 0.606147, predicted_tag_count = 2.4200053, recall = 0.4903184, recall_top10 = 0.8074024, recall_top2 = 0.45428208, recall_top5 = 0.7111479
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5516: trained/video/base/20191209_064155/model.ckpt-5516
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-5516
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873751'/saved_model.pb
# INFO:tensorflow:global_step/sec: 136.909
# INFO:tensorflow:loss = 0.023891084, step = 6000 (7.304 sec)
# INFO:tensorflow:global_step/sec: 283.758
# INFO:tensorflow:loss = 0.014996096, step = 7000 (3.525 sec)
# INFO:tensorflow:Saving checkpoints for 7297 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:42:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-7297
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:42:41
# INFO:tensorflow:Saving dict for global step 7297: accuracy = 0.99945194, auc = 0.7528956, global_step = 7297, loss = 0.015445947, precision = 0.7031635, predicted_tag_count = 2.1526487, recall = 0.50595677, recall_top10 = 0.8187838, recall_top2 = 0.45898247, recall_top5 = 0.7223224
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7297: trained/video/base/20191209_064155/model.ckpt-7297
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-7297
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873761'/saved_model.pb
# INFO:tensorflow:global_step/sec: 151.25
# INFO:tensorflow:loss = 0.011430567, step = 8000 (6.611 sec)
# INFO:tensorflow:global_step/sec: 300.458
# INFO:tensorflow:loss = 0.0075691254, step = 9000 (3.328 sec)
# INFO:tensorflow:Saving checkpoints for 9314 into trained/video/base/20191209_064155/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:42:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-9314
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:42:51
# INFO:tensorflow:Saving dict for global step 9314: accuracy = 0.99950534, auc = 0.76333493, global_step = 9314, loss = 0.0075696814, precision = 0.7609531, predicted_tag_count = 2.0711064, recall = 0.5267981, recall_top10 = 0.824105, recall_top2 = 0.46149525, recall_top5 = 0.72915125
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9314: trained/video/base/20191209_064155/model.ckpt-9314
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-9314
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873771'/saved_model.pb
# INFO:tensorflow:global_step/sec: 147.112
# INFO:tensorflow:loss = 0.0050432067, step = 10000 (6.798 sec)
# INFO:tensorflow:global_step/sec: 302.84
# INFO:tensorflow:loss = 0.0035883314, step = 11000 (3.302 sec)
# INFO:tensorflow:Saving checkpoints for 11288 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:42:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-11288
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:43:01
# INFO:tensorflow:Saving dict for global step 11288: accuracy = 0.99953634, auc = 0.77097166, global_step = 11288, loss = 0.0043510953, precision = 0.79411, predicted_tag_count = 2.0420978, recall = 0.5420522, recall_top10 = 0.8250806, recall_top2 = 0.4608153, recall_top5 = 0.7298312
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11288: trained/video/base/20191209_064155/model.ckpt-11288
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-11288
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873781'/saved_model.pb
# INFO:tensorflow:global_step/sec: 151.204
# INFO:tensorflow:loss = 0.0026789075, step = 12000 (6.614 sec)
# INFO:tensorflow:global_step/sec: 300.691
# INFO:tensorflow:loss = 0.0019364114, step = 13000 (3.326 sec)
# INFO:tensorflow:Saving checkpoints for 13309 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:43:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-13309
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:43:11
# INFO:tensorflow:Saving dict for global step 13309: accuracy = 0.9995277, auc = 0.77749544, global_step = 13309, loss = 0.0029707882, precision = 0.7710438, predicted_tag_count = 2.153887, recall = 0.5551187, recall_top10 = 0.82307035, recall_top2 = 0.4605197, recall_top5 = 0.72894436
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13309: trained/video/base/20191209_064155/model.ckpt-13309
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-13309
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873791'/saved_model.pb
# INFO:tensorflow:global_step/sec: 143.974
# INFO:tensorflow:loss = 0.0014497227, step = 14000 (6.946 sec)
# INFO:tensorflow:global_step/sec: 289.936
# INFO:tensorflow:loss = 0.0011578392, step = 15000 (3.449 sec)
# INFO:tensorflow:Saving checkpoints for 15184 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:43:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-15184
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:43:21
# INFO:tensorflow:Saving dict for global step 15184: accuracy = 0.99951386, auc = 0.7812549, global_step = 15184, loss = 0.0024554788, precision = 0.7475061, predicted_tag_count = 2.2518795, recall = 0.56265706, recall_top10 = 0.8185473, recall_top2 = 0.45868686, recall_top5 = 0.72456914
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15184: trained/video/base/20191209_064155/model.ckpt-15184
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-15184
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873801'/saved_model.pb
# INFO:tensorflow:global_step/sec: 149.765
# INFO:tensorflow:loss = 0.0009189325, step = 16000 (6.677 sec)
# INFO:tensorflow:global_step/sec: 297.371
# INFO:tensorflow:loss = 0.00078942353, step = 17000 (3.363 sec)
# INFO:tensorflow:Saving checkpoints for 17176 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:43:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-17176
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:43:31
# INFO:tensorflow:Saving dict for global step 17176: accuracy = 0.99949324, auc = 0.78384393, global_step = 17176, loss = 0.0022726974, precision = 0.7188728, predicted_tag_count = 2.3632264, recall = 0.56786, recall_top10 = 0.81375825, recall_top2 = 0.45646968, recall_top5 = 0.71972096
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17176: trained/video/base/20191209_064155/model.ckpt-17176
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-17176
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873811'/saved_model.pb
# INFO:tensorflow:global_step/sec: 149.607
# INFO:tensorflow:loss = 0.0006879076, step = 18000 (6.684 sec)
# INFO:tensorflow:global_step/sec: 298.504
# INFO:tensorflow:loss = 0.0005690479, step = 19000 (3.350 sec)
# INFO:tensorflow:Saving checkpoints for 19163 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (10 secs).
# INFO:tensorflow:global_step/sec: 287.793
# INFO:tensorflow:loss = 0.00053197704, step = 20000 (3.475 sec)
# INFO:tensorflow:global_step/sec: 296.11
# INFO:tensorflow:loss = 0.00043636656, step = 21000 (3.377 sec)
# INFO:tensorflow:global_step/sec: 296.667
# INFO:tensorflow:loss = 0.00042368437, step = 22000 (3.371 sec)
# INFO:tensorflow:Saving checkpoints for 22100 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:43:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-22100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:43:51
# INFO:tensorflow:Saving dict for global step 22100: accuracy = 0.999449, auc = 0.78758794, global_step = 22100, loss = 0.0023598417, precision = 0.6672838, predicted_tag_count = 2.5797293, recall = 0.5753983, recall_top10 = 0.8023768, recall_top2 = 0.45147368, recall_top5 = 0.71126616
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 22100: trained/video/base/20191209_064155/model.ckpt-22100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-22100
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873831'/saved_model.pb
# INFO:tensorflow:global_step/sec: 150.579
# INFO:tensorflow:loss = 0.0003714651, step = 23000 (6.641 sec)
# INFO:tensorflow:global_step/sec: 296.238
# INFO:tensorflow:loss = 0.00033864393, step = 24000 (3.376 sec)
# INFO:tensorflow:Saving checkpoints for 24094 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:43:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-24094
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:44:01
# INFO:tensorflow:Saving dict for global step 24094: accuracy = 0.99943364, auc = 0.7878905, global_step = 24094, loss = 0.0024540003, precision = 0.65215206, predicted_tag_count = 2.642434, recall = 0.57601917, recall_top10 = 0.79945016, recall_top2 = 0.4502025, recall_top5 = 0.7083691
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24094: trained/video/base/20191209_064155/model.ckpt-24094
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-24094
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873841'/saved_model.pb
# INFO:tensorflow:global_step/sec: 151.68
# INFO:tensorflow:loss = 0.0003583129, step = 25000 (6.593 sec)
# INFO:tensorflow:global_step/sec: 294.469
# INFO:tensorflow:loss = 0.00033045746, step = 26000 (3.396 sec)
# INFO:tensorflow:Saving checkpoints for 26098 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:44:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-26098
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:44:11
# INFO:tensorflow:Saving dict for global step 26098: accuracy = 0.99942064, auc = 0.78882927, global_step = 26098, loss = 0.0025547633, precision = 0.63939947, predicted_tag_count = 2.7039888, recall = 0.57791114, recall_top10 = 0.7964348, recall_top2 = 0.44780797, recall_top5 = 0.70635885
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 26098: trained/video/base/20191209_064155/model.ckpt-26098
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-26098
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873851'/saved_model.pb
# INFO:tensorflow:global_step/sec: 148.088
# INFO:tensorflow:loss = 0.00035687865, step = 27000 (6.753 sec)
# INFO:tensorflow:global_step/sec: 295.758
# INFO:tensorflow:loss = 0.00030216327, step = 28000 (3.381 sec)
# INFO:tensorflow:Saving checkpoints for 28059 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:44:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-28059
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:44:21
# INFO:tensorflow:Saving dict for global step 28059: accuracy = 0.999409, auc = 0.78950274, global_step = 28059, loss = 0.0026509, precision = 0.6284074, predicted_tag_count = 2.7577608, recall = 0.579271, recall_top10 = 0.793922, recall_top2 = 0.44632986, recall_top5 = 0.70366865
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 28059: trained/video/base/20191209_064155/model.ckpt-28059
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-28059
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873861'/saved_model.pb
# INFO:tensorflow:global_step/sec: 149.885
# INFO:tensorflow:loss = 0.00032320403, step = 29000 (6.672 sec)
# INFO:tensorflow:Saving checkpoints for 30000 into trained/video/base/20191209_064155/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (10 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:44:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:44:31
# INFO:tensorflow:Saving dict for global step 30000: accuracy = 0.9993978, auc = 0.7898517, global_step = 30000, loss = 0.0027417103, precision = 0.6188178, predicted_tag_count = 2.8039267, recall = 0.5799805, recall_top10 = 0.792237, recall_top2 = 0.44541344, recall_top5 = 0.70103765
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30000: trained/video/base/20191209_064155/model.ckpt-30000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Restoring parameters from trained/video/base/20191209_064155/model.ckpt-30000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/20191209_064155/export/exporter/temp-b'1575873871'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.00028874743.
