# %%
# youtube8m のディレクトリに移動
import os
while os.getcwd().split('/')[-1] != 'youtube8m': os.chdir('..')
os.getcwd()
# Out:
# '/home/jupyter/ASLOpenProject/youtube8m'

# %%
PROJECT = "qwiklabs-gcp-ml-3b4c41182bb8"  # Replace with your PROJECT
BUCKET = "qwiklabs-gcp-ml-3b4c41182bb8"  # Replace with your BUCKET
REGION = "us-central1"            # Choose an available region for Cloud MLE
TFVERSION = "1.14"                # TF version for CMLE to use

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
import shutil
from datetime import datetime
import json
from data import read_dataset, CLASS_NUM
print(CLASS_NUM)
# Out:
# 3862

# %% [markdown]
# # Models
# 特徴量を受け取って、識別用の logits を出力するモデル

# %%
class LinearModel(tf.keras.models.Model):
    def __init__(self, params, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.output_dense = tf.keras.layers.Dense(CLASS_NUM)
    
    def call(self, visual_feature, audio_feature):
        '''
        フィーチャーを受け取って sigmoid の logits を返します
        '''
        return self.output_dense(tf.concat([visual_feature, audio_feature], axis=-1))

# %%
class DNNModel(tf.keras.models.Model):
    def __init__(self, params, *args, **kwargs):
        super().__init__(*args, **kwargs)
        layer_num = params.get('layer_num', 4)
        hidden_dim = params.get('hidden_dim', 1024)
        dropout = params.get('dropout', 0.1)
        kernel_reg = params.get('kernel_regularizer', 0.0)
        print('layer_num: {}\nhidden_dim: {}\ndropout: {}'.format(layer_num, hidden_dim, dropout))
        
        self.hidden_layers = [
            tf.keras.layers.Dense(
                hidden_dim,
                activation='relu',
                kernel_regularizer=tf.keras.regularizers.l1(l=kernel_reg),
            )
            for i in range(layer_num)
        ]
        self.dropout_layers = [tf.keras.layers.Dropout(dropout) for i in range(layer_num)]
        self.output_dense = tf.keras.layers.Dense(CLASS_NUM)
        
    def call(self, visual_feature, audio_feature):
        '''
        フィーチャーを受け取って sigmoid の logits を返します
        '''
        x = tf.concat([visual_feature, audio_feature], axis=-1)
        for hidden_layer, dropout_layer in zip(self.hidden_layers, self.dropout_layers):
            x = hidden_layer(x)
            x = dropout_layer(x)
        return self.output_dense(x)

# %% [markdown]
# # Model Function

# %%
from typing import Dict
from data import read_dataset

def create_model(params):
    model_map = {
        'linear': LinearModel,
        'dnn': DNNModel,
    }
    print('----------------------------------')
    print('Model:', params['model'])
    return model_map[params['model']](params)

def multi_hot(indices):
    return tf.reduce_sum(tf.one_hot(indices, CLASS_NUM), axis=-2)

def recall_topk(probabilities, labels, top_k):
    predicted_topk = tf.math.top_k(probabilities, k=top_k).indices
    predicted_topk_multihot = multi_hot(predicted_topk)
    return tf.metrics.recall(
        labels=labels,
        predictions=predicted_topk_multihot,
    )

def create_metrics(probabilities, labels, params):
    threshold = params.get('threshold', 0.5)
    top_k = params.get('top_k', 5)
    predicted_bool = tf.cast(probabilities >= threshold, tf.float32)
    metrics = {
        'accuracy': tf.metrics.accuracy(labels=labels, predictions=predicted_bool),
        'recall': tf.metrics.recall(labels=labels, predictions=predicted_bool),
        'precision': tf.metrics.precision(labels=labels, predictions=predicted_bool),
        'auc': tf.metrics.auc(labels=labels, predictions=predicted_bool),
        'predicted_tag_count': tf.metrics.mean(tf.math.count_nonzero(predicted_bool, axis=-1)),
    }
    for k in [top_k // 2, top_k, top_k * 2]:
        metrics['recall_top{}'.format(k)] = recall_topk(probabilities, labels, top_k=k)
    return metrics

def model_fn(
    features: Dict[str, tf.Tensor],
    labels: tf.Tensor,
    mode: tf.estimator.ModeKeys,
    params: Dict,
) -> tf.estimator.EstimatorSpec:
    threshold = params.get('threshold', 0.5)
    model = create_model(params)
    logits = model(features['mean_rgb'], features['mean_audio'])
    probabilities = tf.nn.sigmoid(logits)

    loss = None
    train_op = None
    eval_metric_ops = None

    if mode == tf.estimator.ModeKeys.TRAIN or mode == tf.estimator.ModeKeys.EVAL:
        # Convert string label to int
        cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(
            labels=labels,
            logits=logits,
        )
        loss = tf.reduce_mean(cross_entropy)

    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer(learning_rate=params.get('learning_rate', 0.001))
        # Batch Normalization 用
        update_ops = tf.get_collection(key = tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(control_inputs = update_ops):
            train_op = optimizer.minimize(
                loss,
                global_step=tf.train.get_or_create_global_step()
            )
    if mode == tf.estimator.ModeKeys.EVAL:
        eval_metric_ops = create_metrics(probabilities, labels, params)

    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions={
            'probabilities': probabilities,
            'predicted_topk': tf.math.top_k(probabilities, k=params.get('top_k', 5)).indices,
        },
        loss=loss,
        train_op=train_op,
        eval_metric_ops=eval_metric_ops,
    )

# %% [markdown]
# # その他諸々

# %%
def serving_input_fn():
    feature_placeholders = {
        'mean_rgb': tf.placeholder(dtype=tf.float32, shape=[None, 1024], name='serving_mean_rgb'),
        'mean_audio': tf.placeholder(dtype=tf.float32, shape=[None, 128], name='serving_mean_audio'),
    }
    return tf.estimator.export.ServingInputReceiver(
        features=feature_placeholders,
        receiver_tensors=feature_placeholders,
    )

# %%
def train_and_evaluate(output_dir: str, params: Dict) -> None:
    tf.summary.FileWriterCache.clear()
    eval_interval_step = params.get('eval_interval_step', 1000)

    config = tf.estimator.RunConfig(
        model_dir=output_dir,
        save_checkpoints_steps=eval_interval_step,
        log_step_count_steps=params.get('log_interval_step', 100),
    )
    estimator = tf.estimator.Estimator(
        model_fn=model_fn,
        config=config,
        params=params,
    )
    batch_size = params.get('batch_size', 512)
    train_spec = tf.estimator.TrainSpec(
        lambda: read_dataset(
            params['train_data_path'],
            tf.estimator.ModeKeys.TRAIN,
            batch_size,
        ),
        max_steps=params.get('train_steps', 10000),
    )
    exporter = tf.estimator.LatestExporter(
        name='exporter', 
        serving_input_receiver_fn=serving_input_fn,
    )
    eval_spec = tf.estimator.EvalSpec(
        lambda: read_dataset(
            params['eval_data_path'],
            tf.estimator.ModeKeys.EVAL,
            batch_size,
        ),
        exporters=exporter,
        start_delay_secs=params.get('eval_delay_sec', 60),
        throttle_secs=10,
    )

    # Run train_and_evaluate loop
    tf.estimator.train_and_evaluate(
        estimator=estimator, 
        train_spec=train_spec, 
        eval_spec=eval_spec,
    )

# %% [markdown]
# # 学習させる

# %%
#model_name = 'dnn/l2h1024d04r0_lr1e3'
model_name = 'linear'
out_dir = 'trained/video_medium/{}/{}'.format(model_name, datetime.now().strftime('%Y%m%d_%H%M%S'))
os.makedirs(out_dir)
params = {
    'train_data_path': './data/video/train*0.tfrecord',
    'eval_data_path': './data/video/validate*0.tfrecord',
    
    # model params
    'model': 'linear',
    'layer_num': 2,
    'hidden_dim': 1024,
    'dropout': 0.4,
    'kernel_regularizer': 0.0,
    
    # training params
    'batch_size': 512,
    'learning_rate': 0.001,
    'train_steps': 30000,
    'log_interval_step': 500,
    'eval_delay_sec': 1,
    'eval_interval_step': 1000,
}

with open(os.path.join(out_dir, 'params.json'), 'w') as f:
    json.dump(params, f, ensure_ascii=False, indent=2)

train_and_evaluate(out_dir, params)
# Out:
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_device_fn': None, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_num_ps_replicas': 0, '_protocol': None, '_model_dir': 'trained/video_medium/linear/20191209_093804', '_experimental_distribute': None, '_tf_random_seed': None, '_session_creation_timeout_secs': 7200, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_master': '', '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_log_step_count_steps': 500, '_save_checkpoints_steps': 1000, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8ae3e09f28>, '_train_distribute': None, '_task_id': 0, '_num_worker_replicas': 1, '_evaluation_master': ''}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_sequence_example is deprecated. Please use tf.io.parse_single_sequence_example instead.
#
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:loss = 0.70609033, step = 0
# INFO:tensorflow:global_step/sec: 30.727
# INFO:tensorflow:loss = 0.43237665, step = 500 (16.274 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/metrics_impl.py:2200: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:38:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:38:40
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.94765776, auc = 0.76360524, global_step = 1000, loss = 0.30627826, precision = 0.008609174, predicted_tag_count = 202.6227, recall = 0.5792652, recall_top10 = 0.76814216, recall_top2 = 0.43057367, recall_top5 = 0.66832054
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: trained/video_medium/linear/20191209_093804/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884320'/saved_model.pb
# INFO:tensorflow:global_step/sec: 29.8309
# INFO:tensorflow:loss = 0.31357718, step = 1000 (16.761 sec)
# INFO:tensorflow:global_step/sec: 199.931
# INFO:tensorflow:loss = 0.23435871, step = 1500 (2.501 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:38:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:38:53
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.9921359, auc = 0.7526742, global_step = 2000, loss = 0.16867585, precision = 0.050721318, predicted_tag_count = 30.448242, recall = 0.5128385, recall_top10 = 0.77957, recall_top2 = 0.43694913, recall_top5 = 0.68017644
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: trained/video_medium/linear/20191209_093804/model.ckpt-2000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-2000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/
model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:41:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:41:38
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.9995887, auc = 0.79229975, global_step = 15000, loss = 0.0020622306, precision = 0.8387295, predicted_tag_count = 2.0992968, recall = 0.58468723, recall_top10 = 0.8677173, recall_top2 = 0.47815937, recall_top5 = 0.7673055
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: trained/video_medium/linear/20191209_093804/model.ckpt-15000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-15000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884498'/saved_model.pb
# INFO:tensorflow:global_step/sec: 48.3075
# INFO:tensorflow:loss = 0.0018537423, step = 15000 (10.350 sec)
# INFO:tensorflow:global_step/sec: 191.834
# INFO:tensorflow:loss = 0.0017243037, step = 15500 (2.606 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:41:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:41:50
# INFO:tensorflow:Saving dict for global step 16000: accuracy = 0.9995897, auc = 0.7961919, global_step = 16000, loss = 0.0018924596, precision = 0.8328714, predicted_tag_count = 2.1422265, recall = 0.59247655, recall_top10 = 0.86880046, recall_top2 = 0.47937867, recall_top5 = 0.76836914
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: trained/video_medium/linear/20191209_093804/model.ckpt-16000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-16000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884510'/saved_model.pb
# INFO:tensorflow:global_step/sec: 49.8089
# INFO:tensorflow:loss = 0.0016896982, step = 16000 (10.038 sec)
# INFO:tensorflow:global_step/sec: 193.176
# INFO:tensorflow:loss = 0.0016115827, step = 16500 (2.589 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:41:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:42:03
# INFO:tensorflow:Saving dict for global step 17000: accuracy = 0.9995895, auc = 0.79864806, global_step = 17000, loss = 0.0017858157, precision = 0.828296, predicted_tag_count = 2.1719337, recall = 0.59739274, recall_top10 = 0.8687356, recall_top2 = 0.47933975, recall_top5 = 0.769128
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: trained/video_medium/linear/20191209_093804/model.ckpt-17000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-17000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884523'/saved_model.pb
# INFO:tensorflow:global_step/sec: 49.7732
# INFO:tensorflow:loss = 0.0014657642, step = 17000 (10.045 sec)
# INFO:tensorflow:global_step/sec: 193.021
# INFO:tensorflow:loss = 0.0014610755, step = 17500 (2.591 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:42:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:42:15
# INFO:tensorflow:Saving dict for global step 18000: accuracy = 0.9995883, auc = 0.7993571, global_step = 18000, loss = 0.0017183251, precision = 0.82535934, predicted_tag_count = 2.1848438, recall = 0.5988131, recall_top10 = 0.8697085, recall_top2 = 0.47954082, recall_top5 = 0.769796
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: trained/video_medium/linear/20191209_093804/model.ckpt-18000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-18000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884535'/saved_model.pb
# INFO:tensorflow:global_step/sec: 50.1502
# INFO:tensorflow:loss = 0.0013484433, step = 18000 (9.970 sec)
# INFO:tensorflow:global_step/sec: 190.233
# INFO:tensorflow:loss = 0.0013713858, step = 18500 (2.628 sec)
# INFO:tensorflow:Saving checkpoints for 19000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:42:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:42:28
# INFO:tensorflow:Saving dict for global step 19000: accuracy = 0.999587, auc = 0.80175424, global_step = 19000, loss = 0.0016790704, precision = 0.8190803, predicted_tag_count = 2.2192383, recall = 0.60361254, recall_top10 = 0.86953336, recall_top2 = 0.47996238, recall_top5 = 0.7700555
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: trained/video_medium/linear/20191209_093804/model.ckpt-19000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# ...
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:43:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:43:32
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.99957657, auc = 0.8058222, global_step = 24000, loss = 0.0016382417, precision = 0.79821444, predicted_tag_count = 2.3080077, recall = 0.6117651, recall_top10 = 0.8679898, recall_top2 = 0.480144, recall_top5 = 0.76854426
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24000: trained/video_medium/linear/20191209_093804/model.ckpt-24000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-24000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884612'/saved_model.pb
# INFO:tensorflow:global_step/sec: 48.6087
# INFO:tensorflow:loss = 0.0010769742, step = 24000 (10.287 sec)
# INFO:tensorflow:global_step/sec: 189.12
# INFO:tensorflow:loss = 0.0011368266, step = 24500 (2.644 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:43:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:43:44
# INFO:tensorflow:Saving dict for global step 25000: accuracy = 0.99957395, auc = 0.80622584, global_step = 25000, loss = 0.0016421773, precision = 0.7938242, predicted_tag_count = 2.3238478, recall = 0.6125758, recall_top10 = 0.86734766, recall_top2 = 0.47965106, recall_top5 = 0.76810324
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25000: trained/video_medium/linear/20191209_093804/model.ckpt-25000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-25000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884624'/saved_model.pb
# INFO:tensorflow:global_step/sec: 49.9136
# INFO:tensorflow:loss = 0.0011565454, step = 25000 (10.017 sec)
# INFO:tensorflow:global_step/sec: 192.979
# INFO:tensorflow:loss = 0.001044463, step = 25500 (2.591 sec)
# INFO:tensorflow:Saving checkpoints for 26000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:43:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-26000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:43:57
# INFO:tensorflow:Saving dict for global step 26000: accuracy = 0.9995717, auc = 0.80697006, global_step = 26000, loss = 0.0016461953, precision = 0.7898293, predicted_tag_count = 2.341289, recall = 0.6140675, recall_top10 = 0.8669261, recall_top2 = 0.4797808, recall_top5 = 0.7684016
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 26000: trained/video_medium/linear/20191209_093804/model.ckpt-26000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-26000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884637'/saved_model.pb
# INFO:tensorflow:global_step/sec: 49.7955
# INFO:tensorflow:loss = 0.0010230101, step = 26000 (10.043 sec)
# INFO:tensorflow:global_step/sec: 190.641
# INFO:tensorflow:loss = 0.0010367727, step = 26500 (2.621 sec)
# INFO:tensorflow:Saving checkpoints for 27000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:44:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-27000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:44:10
# INFO:tensorflow:Saving dict for global step 27000: accuracy = 0.99956954, auc = 0.8078631, global_step = 27000, loss = 0.0016536899, precision = 0.78539646, predicted_tag_count = 2.3613672, recall = 0.6158576, recall_top10 = 0.8664267, recall_top2 = 0.4796316, recall_top5 = 0.7678957
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 27000: trained/video_medium/linear/20191209_093804/model.ckpt-27000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-27000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884650'/saved_model.pb
# INFO:tensorflow:global_step/sec: 49.738
# INFO:tensorflow:loss = 0.001096723, step = 27000 (10.052 sec)
# INFO:tensorflow:global_step/sec: 193.042
# INFO:tensorflow:loss = 0.0010473263, step = 27500 (2.590 sec)
# INFO:tensorflow:Saving checkpoints for 28000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:44:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:44:22
# INFO:tensorflow:Saving dict for global step 28000: accuracy = 0.9995673, auc = 0.80785567, global_step = 28000, loss = 0.0016595592, precision = 0.78286105, predicted_tag_count = 2.368965, recall = 0.6158446, recall_top10 = 0.8660051, recall_top2 = 0.47932678, recall_top5 = 0.76751304
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 28000: trained/video_medium/linear/20191209_093804/model.ckpt-28000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-28000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884662'/saved_model.pb
# INFO:tensorflow:global_step/sec: 49.6317
# INFO:tensorflow:loss = 0.0010603457, step = 28000 (10.074 sec)
# INFO:tensorflow:global_step/sec: 187.334
# INFO:tensorflow:loss = 0.0010278634, step = 28500 (2.669 sec)
# INFO:tensorflow:Saving checkpoints for 29000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:44:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-29000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:44:35
# INFO:tensorflow:Saving dict for global step 29000: accuracy = 0.99956435, auc = 0.80797726, global_step = 29000, loss = 0.0016662623, precision = 0.77898693, predicted_tag_count = 2.3816993, recall = 0.6160911, recall_top10 = 0.8657003, recall_top2 = 0.47933328, recall_top5 = 0.76715636
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 29000: trained/video_medium/linear/20191209_093804/model.ckpt-29000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-29000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884675'/saved_model.pb
# INFO:tensorflow:global_step/sec: 49.3611
# INFO:tensorflow:loss = 0.0010157981, step = 29000 (10.129 sec)
# INFO:tensorflow:global_step/sec: 190.283
# INFO:tensorflow:loss = 0.0010634612, step = 29500 (2.628 sec)
# INFO:tensorflow:Saving checkpoints for 30000 into trained/video_medium/linear/20191209_093804/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T09:44:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-09-09:44:48
# INFO:tensorflow:Saving dict for global step 30000: accuracy = 0.9995633, auc = 0.8094576, global_step = 30000, loss = 0.0016742435, precision = 0.77551, predicted_tag_count = 2.4038868, recall = 0.61905503, recall_top10 = 0.8649674, recall_top2 = 0.47924894, recall_top5 = 0.76667637
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30000: trained/video_medium/linear/20191209_093804/model.ckpt-30000
# INFO:tensorflow:Calling model_fn.
# ----------------------------------
# Model: linear
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained/video_medium/linear/20191209_093804/model.ckpt-30000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video_medium/linear/20191209_093804/export/exporter/temp-b'1575884688'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.0009920102.
