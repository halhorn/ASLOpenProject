# %%
# youtube8m のディレクトリに移動
import os
while os.getcwd().split('/')[-1] != 'youtube8m': os.chdir('..')
os.getcwd()
# Out:
# '/home/jupyter/ASLOpenProject/youtube8m'

# %%
PROJECT = "qwiklabs-gcp-ml-3b4c41182bb8"  # Replace with your PROJECT
BUCKET = "qwiklabs-gcp-ml-3b4c41182bb8"  # Replace with your BUCKET
REGION = "us-central1"            # Choose an available region for Cloud MLE
TFVERSION = "1.14"                # TF version for CMLE to use

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
import shutil
from data import read_dataset, CLASS_NUM
print(CLASS_NUM)
# Out:
# 3862

# %%
TRAIN_DATA_PATH = './data/video/train*.tfrecord'
EVAL_DATA_PATH = './data/video/validate*.tfrecord'

# %%
class LinearModel(tf.keras.models.Model):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.output_dense = tf.keras.layers.Dense(CLASS_NUM)
    
    def call(self, visual_feature, audio_feature):
        '''
        フィーチャーを受け取って sigmoid の logits を返します
        '''
        return self.output_dense(tf.concat([visual_feature, audio_feature], axis=-1))

# %%
from typing import Dict
from data import read_dataset

def create_model(params):
    model_map = {
        'linear': LinearModel,
    }
    return model_map[params['model']](params)

def model_fn(
    features: Dict[str, tf.Tensor],
    labels: tf.Tensor,
    mode: tf.estimator.ModeKeys,
    params: Dict,
) -> tf.estimator.EstimatorSpec:
    threshold = params.get('threshold', 0.5)
    model = create_model(params)
    logits = model(features['mean_rgb'], features['mean_audio'])
    probabilities = tf.nn.sigmoid(logits)
    predicted_multihot = tf.cast(probabilities >= threshold, tf.float32)

    loss = None
    train_op = None
    eval_metric_ops = None

    if mode == tf.estimator.ModeKeys.TRAIN or mode == tf.estimator.ModeKeys.EVAL:
        # Convert string label to int
        cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(
            labels=labels,
            logits=logits,
        )
        loss = tf.reduce_mean(cross_entropy)

    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer(learning_rate=params.get('learning_rate', 0.001))
        # Batch Normalization 用
        update_ops = tf.get_collection(key = tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(control_inputs = update_ops):
            train_op = optimizer.minimize(
                loss,
                global_step=tf.train.get_or_create_global_step()
            )
        eval_metric_ops = None
    if mode == tf.estimator.ModeKeys.EVAL:
        train_op = None
        eval_metric_ops = {
            'accuracy': tf.metrics.accuracy(labels=labels, predictions=predicted_multihot)
        }

    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions={
            'probabilities': probabilities,
            'predicted_multihot': predicted_multihot,
        },
        loss=loss,
        train_op=train_op,
        eval_metric_ops=eval_metric_ops,
    )

# %%
def serving_input_fn():
    feature_placeholders = {
        'mean_rgb': tf.placeholder(dtype=tf.float32, shape=[None, 1024], name='serving_mean_rgb'),
        'mean_audio': tf.placeholder(dtype=tf.float32, shape=[None, 128], name='serving_mean_audio'),
    }
    return tf.estimator.export.ServingInputReceiver(
        features=feature_placeholders,
        receiver_tensors=feature_placeholders,
    )

# %%
def train_and_evaluate(output_dir: str, params: Dict) -> None:
    tf.summary.FileWriterCache.clear()

    config = tf.estimator.RunConfig(
        model_dir=output_dir,
        save_checkpoints_secs=params.get('eval_interval', 60),
    )
    estimator = tf.estimator.Estimator(
        model_fn=model_fn,
        config=config,
        params=params,
    )
    batch_size = params.get('batch_size', 512)
    train_spec = tf.estimator.TrainSpec(
        lambda: read_dataset(
            params['train_data_path'],
            tf.estimator.ModeKeys.TRAIN,
            batch_size,
        ),
        max_steps=params.get('train_steps', 10000),
    )
    exporter = tf.estimator.LatestExporter(
        name='exporter', 
        serving_input_receiver_fn=serving_input_fn,
    )
    eval_spec = tf.estimator.EvalSpec(
        lambda: read_dataset(
            params['eval_data_path'],
            tf.estimator.ModeKeys.EVAL,
            batch_size,
        ),
        exporters=exporter,
        start_delay_secs=params.get('eval_delay_sec', 60),
        throttle_secs=params.get('eval_throttle_sec', 60),
    )

    # Run train_and_evaluate loop
    tf.estimator.train_and_evaluate(
        estimator=estimator, 
        train_spec=train_spec, 
        eval_spec=eval_spec,
    )

# %%
out_dir = 'trained/video/base/'
shutil.rmtree(out_dir, ignore_errors=True)
params = {
    'train_data_path': TRAIN_DATA_PATH,
    'eval_data_path': EVAL_DATA_PATH,
    'model': 'linear',
    'batch_size': 256,
    'learning_rate': 0.001,
    'train_steps': 10000,
    'eval_delay_sec': 1,
}

train_and_evaluate(out_dir, params)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'trained/video/base/', '_num_ps_replicas': 0, '_experimental_distribute': None, '_is_chief': True, '_train_distribute': None, '_num_worker_replicas': 1, '_session_creation_timeout_secs': 7200, '_save_checkpoints_steps': None, '_global_id_in_cluster': 0, '_experimental_max_worker_delay_secs': None, '_eval_distribute': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f14bf1fce48>, '_service': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_save_checkpoints_secs': 60, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_protocol': None, '_device_fn': None, '_master': '', '_task_type': 'worker', '_tf_random_seed': None}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_sequence_example is deprecated. Please use tf.io.parse_single_sequence_example instead.
#
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into trained/video/base/model.ckpt.
# INFO:tensorflow:loss = 0.70684546, step = 0
# INFO:tensorflow:global_step/sec: 16.5167
# INFO:tensorflow:loss = 0.60206515, step = 100 (6.058 sec)
# INFO:tensorflow:global_step/sec: 16.7517
# INFO:tensorflow:loss = 0.5355758, step = 200 (5.968 sec)
# INFO:tensorflow:global_step/sec: 16.5371
# INFO:tensorflow:loss = 0.5209992, step = 300 (6.048 sec)
# INFO:tensorflow:global_step/sec: 16.5535
# INFO:tensorflow:loss = 0.46547335, step = 400 (6.039 sec)
# INFO:tensorflow:global_step/sec: 16.4703
# INFO:tensorflow:loss = 0.42159286, step = 500 (6.072 sec)
# INFO:tensorflow:global_step/sec: 16.5725
# INFO:tensorflow:loss = 0.3735881, step = 600 (6.035 sec)
# INFO:tensorflow:global_step/sec: 16.75
# INFO:tensorflow:loss = 0.40481493, step = 700 (5.968 sec)
# INFO:tensorflow:global_step/sec: 16.6371
# INFO:tensorflow:loss = 0.34807724, step = 800 (6.011 sec)
# INFO:tensorflow:global_step/sec: 16.529
# INFO:tensorflow:loss = 0.32307288, step = 900 (6.050 sec)
# INFO:tensorflow:Saving checkpoints for 981 into trained/video/base/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12
model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:47:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/model.ckpt-8406
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:47:44
# INFO:tensorflow:Saving dict for global step 8406: accuracy = 0.9994668, global_step = 8406, loss = 0.010272192
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8406: trained/video/base/model.ckpt-8406
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from trained/video/base/model.ckpt-8406
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/export/exporter/temp-b'1575730064'/saved_model.pb
# INFO:tensorflow:global_step/sec: 10.5574
# INFO:tensorflow:loss = 0.008740281, step = 8500 (9.474 sec)
# INFO:tensorflow:global_step/sec: 16.7228
# INFO:tensorflow:loss = 0.008763294, step = 8600 (5.980 sec)
# INFO:tensorflow:global_step/sec: 16.7513
# INFO:tensorflow:loss = 0.008625008, step = 8700 (5.969 sec)
# INFO:tensorflow:global_step/sec: 16.7653
# INFO:tensorflow:loss = 0.007614437, step = 8800 (5.963 sec)
# INFO:tensorflow:global_step/sec: 16.6999
# INFO:tensorflow:loss = 0.007925676, step = 8900 (5.988 sec)
# INFO:tensorflow:global_step/sec: 16.8511
# INFO:tensorflow:loss = 0.0077638533, step = 9000 (5.936 sec)
# INFO:tensorflow:global_step/sec: 16.8037
# INFO:tensorflow:loss = 0.0073218765, step = 9100 (5.949 sec)
# INFO:tensorflow:global_step/sec: 16.8378
# INFO:tensorflow:loss = 0.00686144, step = 9200 (5.939 sec)
# INFO:tensorflow:global_step/sec: 16.7719
# INFO:tensorflow:loss = 0.0069415113, step = 9300 (5.965 sec)
# INFO:tensorflow:Saving checkpoints for 9355 into trained/video/base/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:48:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/model.ckpt-9355
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:48:44
# INFO:tensorflow:Saving dict for global step 9355: accuracy = 0.9995006, global_step = 9355, loss = 0.0074707204
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9355: trained/video/base/model.ckpt-9355
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from trained/video/base/model.ckpt-9355
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/export/exporter/temp-b'1575730124'/saved_model.pb
# INFO:tensorflow:global_step/sec: 10.5472
# INFO:tensorflow:loss = 0.0065788385, step = 9400 (9.481 sec)
# INFO:tensorflow:global_step/sec: 16.8146
# INFO:tensorflow:loss = 0.0063371896, step = 9500 (5.947 sec)
# INFO:tensorflow:global_step/sec: 16.991
# INFO:tensorflow:loss = 0.006700583, step = 9600 (5.883 sec)
# INFO:tensorflow:global_step/sec: 16.8085
# INFO:tensorflow:loss = 0.005322204, step = 9700 (5.951 sec)
# INFO:tensorflow:global_step/sec: 16.9816
# INFO:tensorflow:loss = 0.005678187, step = 9800 (5.889 sec)
# INFO:tensorflow:global_step/sec: 16.8692
# INFO:tensorflow:loss = 0.0054052095, step = 9900 (5.926 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into trained/video/base/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:49:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained/video/base/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:49:26
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.9995265, global_step = 10000, loss = 0.006132295
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: trained/video/base/model.ckpt-10000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from trained/video/base/model.ckpt-10000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained/video/base/export/exporter/temp-b'1575730166'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.005347633.
